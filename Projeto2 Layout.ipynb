# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 2

# %% [markdown]
# ___
# ## Nome 1: João Laet Toledo César
#
# ## Nome 2: Vinicius de Paiva Hsu
#
# ___

# %% [markdown]
# ___
#
# ## 1. Problema
#
# O Classificador Naive-Bayes, o qual se baseia no uso do teorema de Bayes, é largamente utilizado em filtros anti-spam de e-mails. O classificador permite calcular qual a probabilidade de uma mensagem ser SPAM considerando as palavras em seu conteúdo e, de forma complementar, permite calcular a probabilidade de uma mensagem ser HAM dada as palavras descritas na mensagem.
#
# Para realizar o MVP (minimum viable product) do projeto, você precisa programar uma versão do classificador que "aprende" o que é uma mensagem SPAM considerando uma base de treinamento e comparar o desempenho dos resultados com uma base de testes.

# %% [markdown]
# ___
# ## 2. Separação da base de dados em Treinamento e Teste
#
# A base de dados deve ser separada em duas partes, aleatoriamente, considerando:
#
#     75% dos dados para a parte Treinamento; e
#     25% dos dados para a parte Teste.

# %%
import pandas as pd
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Camila\OneDrive - Insper - Institudo de Ensino e Pesquisa\Insper\3 B\DP Ciência dos Dados\Projeto 2

# %%
database = pd.read_excel('spamham.xlsx')

# %%
database
data_treino =
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d7b642fa62c3> in <module>()
#       1 database
# ----> 2 data_treino = round(0.75 * nrow(database))
#
# NameError: name 'nrow' is not defined

# %%
database_limpo=[]

for i in range(0,database.Email.size-1):
    database_limpo.append(str(database.iloc[i,0]).split())

palavras=[]
for i in database_limpo:
    for c in i:
        if c not in palavras:
            palavras.append(c)

# %%
palavras
# Out:
# ['Go',
#  'until',
#  'jurong',
#  'point,',
#  'crazy..',
#  'Available',
#  'only',
#  'in',
#  'bugis',
#  'n',
#  'great',
#  'world',
#  'la',
#  'e',
#  'buffet...',
#  'Cine',
#  'there',
#  'got',
#  'amore',
#  'wat...',
#  'Ok',
#  'lar...',
#  'Joking',
#  'wif',
#  'u',
#  'oni...',
#  'Free',
#  'entry',
#  '2',
#  'a',
#  'wkly',
#  'comp',
#  'to',
#  'win',
#  'FA',
#  'Cup',
#  'final',
#  'tkts',
#  '21st',
#  'May',
#  '2005.',
#  'Text',
#  '87121',
#  'receive',
#  'question(std',
#  'txt',
#  "rate)T&C's",
#  'apply',
#  "08452810075over18's",
#  'U',
#  'dun',
#  'say',
#  'so',
#  'early',
#  'hor...',
#  'c',
#  'already',
#  'then',
#  'say...',
#  'Nah',
#  'I',
#  "don't",
#  'think',
#  'he',
#  'goes',
#  'usf,',
#  'lives',
#  'around',
#  'here',
#  'though',
#  'FreeMsg',
#  'Hey',
#  'darling',
#  "it's",
#  'been',
#  '3',
#  "week's",
#  'now',
#  'and',
#  'no',
#  'word',
#  'back!',
#  "I'd",
#  'like',
#  'some',
#  'fun',
#  'you',
#  'up',
#  'for',
#  'it',
#  'still?',
#  'Tb',
#  'ok!',
#  'XxX',
#  'std',
#  'chgs',
#  'send,',
#  'å£1.50',
#  'rcv',
#  'Even',
#  'my',
#  'brother',
#  'is',
#  'not',
#  'speak',
#  'with',
#  'me.',
#  'They',
#  'treat',
#  'me',
#  'aids',
#  'patent.',
#  'As',
#  'per',
#  'your',
#  'request',
#  "'Melle",
#  'Melle',
#  '(Oru',
#  'Minnaminunginte',
#  'Nurungu',
#  "Vettam)'",
#  'has',
#  'set',
#  'as',
#  'callertune',
#  'all',
#  'Callers.',
#  'Press',
#  '*9',
#  'copy',
#  'friends',
#  'Callertune',
#  'WINNER!!',
#  'valued',
#  'network',
#  'customer',
#  'have',
#  'selected',
#  'receivea',
#  'å£900',
#  'prize',
#  'reward!',
#  'To',
#  'claim',
#  'call',
#  '09061701461.',
#  'Claim',
#  'code',
#  'KL341.',
#  'Valid',
#  '12',
#  'hours',
#  'only.',
#  'Had',
#  'mobile',
#  '11',
#  'months',
#  'or',
#  'more?',
#  'R',
#  'entitled',
#  'Update',
#  'the',
#  'latest',
#  'colour',
#  'mobiles',
#  'camera',
#  'Free!',
#  'Call',
#  'The',
#  'Mobile',
#  'Co',
#  'FREE',
#  'on',
#  '08002986030',
#  "I'm",
#  'gonna',
#  'be',
#  'home',
#  'soon',
#  'i',
#  'want',
#  'talk',
#  'about',
#  'this',
#  'stuff',
#  'anymore',
#  'tonight,',
#  'k?',
#  "I've",
#  'cried',
#  'enough',
#  'today.',
#  'SIX',
#  'chances',
#  'CASH!',
#  'From',
#  '100',
#  '20,000',
#  'pounds',
#  'txt>',
#  'CSH11',
#  'send',
#  '87575.',
#  'Cost',
#  '150p/day,',
#  '6days,',
#  '16+',
#  'TsandCs',
#  'Reply',
#  'HL',
#  '4',
#  'info',
#  'URGENT!',
#  'You',
#  'won',
#  '1',
#  'week',
#  'membership',
#  'our',
#  'å£100,000',
#  'Prize',
#  'Jackpot!',
#  'Txt',
#  'word:',
#  'CLAIM',
#  'No:',
#  '81010',
#  'T&C',
#  'www.dbuk.net',
#  'LCCLTD',
#  'POBOX',
#  '4403LDNW1A7RW18',
#  'searching',
#  'right',
#  'words',
#  'thank',
#  'breather.',
#  'promise',
#  'wont',
#  'take',
#  'help',
#  'granted',
#  'will',
#  'fulfil',
#  'promise.',
#  'wonderful',
#  'blessing',
#  'at',
#  'times.',
#  'HAVE',
#  'A',
#  'DATE',
#  'ON',
#  'SUNDAY',
#  'WITH',
#  'WILL!!',
#  'XXXMobileMovieClub:',
#  'use',
#  'credit,',
#  'click',
#  'WAP',
#  'link',
#  'next',
#  'message',
#  'here>>',
#  'http://wap.',
#  'xxxmobilemovieclub.com?n=QJKGIGHJJGCBL',
#  'Oh',
#  "k...i'm",
#  'watching',
#  'here:)',
#  'Eh',
#  'remember',
#  'how',
#  'spell',
#  'his',
#  'name...',
#  'Yes',
#  'did.',
#  'He',
#  'v',
#  'naughty',
#  'make',
#  'wet.',
#  'Fine',
#  'if',
#  'thatåÕs',
#  'way',
#  'feel.',
#  'ThatåÕs',
#  'its',
#  'gota',
#  'b',
#  'England',
#  'Macedonia',
#  '-',
#  'dont',
#  'miss',
#  'goals/team',
#  'news.',
#  'ur',
#  'national',
#  'team',
#  '87077',
#  'eg',
#  'ENGLAND',
#  'Try:WALES,',
#  'SCOTLAND',
#  '4txt/Ì¼1.20',
#  'POBOXox36504W45WQ',
#  'Is',
#  'that',
#  'seriously',
#  'name?',
#  'I‰Û÷m',
#  'going',
#  'try',
#  'ha',
#  'joking',
#  'So',
#  'Ì_',
#  'pay',
#  'first',
#  'Then',
#  'when',
#  'da',
#  'stock',
#  'comin...',
#  'Aft',
#  'finish',
#  'lunch',
#  'go',
#  'str',
#  'down',
#  'lor.',
#  'Ard',
#  'smth',
#  'already?',
#  'Ffffffffff.',
#  'Alright',
#  'can',
#  'meet',
#  'sooner?',
#  'Just',
#  'forced',
#  'myself',
#  'eat',
#  'slice.',
#  'really',
#  'hungry',
#  'tho.',
#  'This',
#  'sucks.',
#  'Mark',
#  'getting',
#  'worried.',
#  'knows',
#  'sick',
#  'turn',
#  'pizza.',
#  'Lol',
#  'always',
#  'convincing.',
#  'Did',
#  'catch',
#  'bus',
#  '?',
#  'Are',
#  'frying',
#  'an',
#  'egg',
#  'tea?',
#  'eating',
#  "mom's",
#  'left',
#  'over',
#  'dinner',
#  'Do',
#  'feel',
#  'Love',
#  'back',
#  '&amp;',
#  "we're",
#  'packing',
#  'car',
#  'now,',
#  "I'll",
#  'let',
#  'know',
#  "there's",
#  'room',
#  'Ahhh.',
#  'Work.',
#  'vaguely',
#  'that!',
#  'What',
#  'does',
#  'like?',
#  'Wait',
#  "that's",
#  'still',
#  'clear,',
#  'were',
#  'sure',
#  'being',
#  'sarcastic',
#  'why',
#  'x',
#  "doesn't",
#  'live',
#  'us',
#  'Yeah',
#  'was',
#  'apologetic.',
#  'had',
#  'fallen',
#  'out',
#  'she',
#  'actin',
#  'spoilt',
#  'child',
#  'caught',
#  'that.',
#  'Till',
#  '2!',
#  'But',
#  'we',
#  "won't",
#  'there!',
#  'Not',
#  'doing',
#  'too',
#  'badly',
#  'cheers.',
#  'You?',
#  'K',
#  'tell',
#  'anything',
#  'you.',
#  'For',
#  'fear',
#  'of',
#  'fainting',
#  'housework',
#  'just',
#  'did?',
#  'Quick',
#  'cuppa',
#  'Thanks',
#  'subscription',
#  'Ringtone',
#  'UK',
#  'charged',
#  'å£5/month',
#  'Please',
#  'confirm',
#  'by',
#  'replying',
#  'YES',
#  'NO.',
#  'If',
#  'reply',
#  'NO',
#  'Yup...',
#  'look',
#  'timings',
#  'msg',
#  'again...',
#  'Xuhui',
#  'learn',
#  '2nd',
#  'may',
#  'but',
#  'her',
#  'lesson',
#  '8am',
#  'Oops,',
#  "roommate's",
#  'done',
#  'see',
#  'letter',
#  'B',
#  'Anything',
#  'lor...',
#  'decide...',
#  'Hello!',
#  "How's",
#  'did',
#  'saturday',
#  'go?',
#  'texting',
#  "you'd",
#  'decided',
#  'do',
#  'tomo.',
#  "i'm",
#  'trying',
#  'invite',
#  'anything!',
#  'Pls',
#  'ahead',
#  'watts.',
#  'wanted',
#  'sure.',
#  'weekend.',
#  'Abiola',
#  'forget',
#  ',',
#  'need',
#  'you,',
#  'crave',
#  '...',
#  'most',
#  'love',
#  'sweet',
#  'Arabian',
#  'steed',
#  'Mmmmmm',
#  'Yummy',
#  '07732584351',
#  'Rodger',
#  'Burns',
#  'MSG',
#  '=',
#  'We',
#  'tried',
#  're',
#  'sms',
#  'free',
#  'nokia',
#  '+',
#  'camcorder.',
#  '08000930705',
#  'delivery',
#  'tomorrow',
#  'WHO',
#  'ARE',
#  'YOU',
#  'SEEING?',
#  'Great!',
#  'hope',
#  'man',
#  'well',
#  'endowed.',
#  'am',
#  '&lt;#&gt;',
#  'inches...',
#  'No',
#  'calls..messages..missed',
#  'calls',
#  "Didn't",
#  'get',
#  'hep',
#  'immunisation',
#  'nigeria.',
#  'Fair',
#  'enough,',
#  'on?',
#  'hopefully,',
#  'tyler',
#  "can't",
#  'could',
#  'maybe',
#  'ask',
#  'bit',
#  'stubborn',
#  'am.',
#  "didn't",
#  'even',
#  'hospital.',
#  'kept',
#  'telling',
#  'weak',
#  'sucker.',
#  'Hospitals',
#  'are',
#  'suckers.',
#  'thinked',
#  'First',
#  'time',
#  'saw',
#  'class.',
#  'gram',
#  'usually',
#  'runs',
#  'half',
#  'eighth',
#  'smarter',
#  'gets',
#  'almost',
#  'whole',
#  'second',
#  'fyi',
#  'ride',
#  'morning',
#  "he's",
#  'crashing',
#  'place',
#  'tonight',
#  'Wow.',
#  'never',
#  'realized',
#  'embarassed',
#  'accomodations.',
#  'thought',
#  'liked',
#  'it,',
#  'since',
#  'best',
#  'seemed',
#  'happy',
#  '\\the',
#  'cave\\".',
#  'sorry',
#  'more',
#  'give.',
#  'offered.',
#  'embarassing."',
#  'SMS.',
#  'ac',
#  'Sptv:',
#  'New',
#  'Jersey',
#  'Devils',
#  'Detroit',
#  'Red',
#  'Wings',
#  'play',
#  'Ice',
#  'Hockey.',
#  'Correct',
#  'Incorrect?',
#  'End?',
#  'END',
#  'SPTV',
#  'what',
#  'Mallika',
#  'Sherawat',
#  'yesterday?',
#  'Find',
#  '@',
#  '&lt;URL&gt;',
#  'Congrats!',
#  'year',
#  'special',
#  'cinema',
#  'pass',
#  'yours.',
#  '09061209465',
#  'now!',
#  'C',
#  'Suprman',
#  'V,',
#  'Matrix3,',
#  'StarWars3,',
#  'etc',
#  'FREE!',
#  'bx420-ip4-5we.',
#  '150pm.',
#  'Dont',
#  'out!',
#  'Sorry,',
#  'later',
#  'meeting.',
#  'Tell',
#  'where',
#  'reached',
#  'Yes..gauti',
#  'sehwag',
#  'odi',
#  'series.',
#  'Your',
#  'pick',
#  '$1',
#  'burger',
#  'yourself',
#  'home.',
#  'move.',
#  'Pain',
#  'killing',
#  'Ha',
#  'good',
#  'joke.',
#  'Girls',
#  'situation',
#  'seekers.',
#  'Its',
#  'part',
#  'checking',
#  'IQ',
#  'Sorry',
#  'roommates',
#  'took',
#  'forever,',
#  'ok',
#  'come',
#  'now?',
#  'lar',
#  'double',
#  'check',
#  'hair',
#  'dresser',
#  'said',
#  'wun',
#  'cut',
#  'short.',
#  'nice.',
#  'customer,',
#  'pleased',
#  'advise',
#  'following',
#  'recent',
#  'review',
#  'Mob',
#  'No.',
#  'awarded',
#  'å£1500',
#  'Bonus',
#  'Prize,',
#  '09066364589',
#  'Today',
#  '\\song',
#  'dedicated',
#  'day..\\"',
#  'Which',
#  'song',
#  'dedicate',
#  'me?',
#  'Send',
#  'valuable',
#  'frnds',
#  'rply',
#  'me..."',
#  'Urgent',
#  'UR',
#  'complimentary',
#  'trip',
#  'EuroDisinc',
#  'Trav,',
#  'Aco&Entry41',
#  'Or',
#  'å£1000.',
#  'DIS',
#  '18+6*å£1.50(moreFrmMob.',
#  'ShrAcomOrSglSuplt)10,',
#  'LS1',
#  '3AJ',
#  'hear',
#  'new',
#  '\\Divorce',
#  'Barbie\\"?',
#  'It',
#  'comes',
#  "Ken's",
#  'stuff!"',
#  'plane',
#  'give',
#  'month',
#  'end.',
#  'Wah',
#  'lucky',
#  'man...',
#  'save',
#  'money...',
#  'Hee...',
#  'Finished',
#  'class',
#  'HI',
#  'BABE',
#  'IM',
#  'AT',
#  'HOME',
#  'NOW',
#  'WANNA',
#  'DO',
#  'SOMETHING?',
#  'XX',
#  'K..k:)where',
#  'you?how',
#  'performed?',
#  'now...',
#  'waiting',
#  'machan.',
#  'once',
#  'free.',
#  'Thats',
#  'cool.',
#  'gentleman',
#  'dignity',
#  'respect.',
#  'peoples',
#  'very',
#  'much:)',
#  'shy',
#  'pa.',
#  'Does',
#  'operate',
#  'after',
#  'same',
#  'here.',
#  'Still',
#  'looking',
#  'job.',
#  'How',
#  'much',
#  "Ta's",
#  'earn',
#  'there.',
#  'K.',
#  'ah?',
#  'hi',
#  'Yup',
#  'stop.',
#  'later,',
#  'network.',
#  'urgnt,',
#  'real',
#  'yo?',
#  'tickets',
#  'one',
#  'jacket',
#  'done.',
#  'used',
#  'multis.',
#  'started',
#  'requests',
#  'pain',
#  'came',
#  'bed.',
#  'Double',
#  'coins',
#  'factory',
#  'too.',
#  'gotta',
#  'cash',
#  'nitros.',
#  'babe',
#  'Ela',
#  'kano.,il',
#  'download,',
#  'wen',
#  'free..',
#  'do!',
#  'Don‰Û÷t',
#  'stand',
#  'close',
#  'tho-',
#  'you‰Û÷ll',
#  'something!',
#  'pain.',
#  'another',
#  'night?',
#  'spent',
#  'late',
#  'afternoon',
#  'casualty',
#  'means',
#  "haven't",
#  'any',
#  'y',
#  'stuff42moro',
#  'includes',
#  'sheets',
#  'Sorry.',
#  'Smile',
#  'Pleasure',
#  'trouble',
#  'pours',
#  'Rain',
#  'sum1',
#  'Hurts',
#  'becoz',
#  'SOMEONE',
#  'Loves',
#  'Smiling!!',
#  'service',
#  'representative',
#  '0800',
#  '169',
#  '6031',
#  'between',
#  '10am-9pm',
#  'WON',
#  'guaranteed',
#  'å£1000',
#  'å£5000',
#  'prize!',
#  'Havent',
#  'planning',
#  'buy',
#  'later.',
#  'lido',
#  '530',
#  'show',
#  'afternoon.',
#  'work',
#  'ringtone',
#  'collected.',
#  'Simply',
#  'text',
#  'password',
#  '\\MIX\\"',
#  '85069',
#  'verify.',
#  'Get',
#  'Usher',
#  'Britney.',
#  'FML',
#  'Watching',
#  'telugu',
#  'movie..wat',
#  'abt',
#  'u?',
#  'see.',
#  'When',
#  'loads',
#  'loans',
#  'Hi.',
#  'Wk',
#  'hols',
#  'run.',
#  'Forgot',
#  'hairdressers',
#  'appointment',
#  'four',
#  'shower',
#  'beforehand.',
#  'cause',
#  'prob',
#  'u?\\"',
#  'nan',
#  'anymore.',
#  'nothing',
#  'else',
#  'say.',
#  'Okay',
#  'name',
#  'price',
#  'long',
#  'legal!',
#  'Wen',
#  'them',
#  'up?',
#  'Y',
#  'ave',
#  'ams',
#  'xx',
#  'buy.',
#  'And',
#  'gone',
#  '4the',
#  'driving',
#  'test',
#  'yet.',
#  'wow.',
#  "You're",
#  'right!',
#  'mean',
#  'guess',
#  'gave',
#  'boston',
#  'men',
#  'changed',
#  'search',
#  'location',
#  'nyc,',
#  'something',
#  'changed.',
#  'Cuz',
#  'signin',
#  'page',
#  'says',
#  'boston.',
#  'Umma',
#  'life',
#  'vava',
#  'umma',
#  'lot',
#  'dear',
#  'wishes',
#  'birthday.',
#  'making',
#  'birthday',
#  'truly',
#  'memorable.',
#  'Aight,',
#  'hit',
#  'would',
#  'ip',
#  'address',
#  'considering',
#  'computer',
#  "isn't",
#  'minecraft',
#  'server',
#  'know!',
#  'Grumpy',
#  'old',
#  ...]

# %% [markdown]
# ___
# ## 3. Classificador Naive-Bayes

# %% [markdown]
# ___
# ## 4. Curva ROC

# %% [markdown]
# ___
# ## 5. Qualidade do Classificador alterando a base de treinamento
