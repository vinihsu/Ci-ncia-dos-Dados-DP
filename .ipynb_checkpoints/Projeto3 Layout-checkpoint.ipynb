# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 3 - INSPER

# %% [markdown]
# ___
# ## Nome 1 - João Laet Toledo César
#
# ## Nome 2 - Pedro Isidoro
#
# ## Nome 3 - Vinicius Hsu
#
# ___

# %% [markdown]
# ___
#
# ## INTRODUÇÃO

# %% [markdown]
# O objetivo do grupo, neste projeto, é construir uma base de dados sólida para que seja possível criar diversos modelos preditivos a fim de se encontrar uma variável alvo a partir de outras dadas pelo usário.
#
# O tema abordado se refere a carros, com o objetivo de se descobrir o consumo de um automóvel, dado sua potência, número de cilindros, capacidade volumétrica do motor, agilidade, peso, ano e marca do carro.

# %% [markdown]
# ___
# ## MINERANDO DADOS e CARACTERÍSTICAS DO DATASET

# %% [markdown]
# [Detalhe aqui as características da base de dados além da análise descritiva.]

# %%
import pandas as pd
import os
import numpy as np

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Vinicius\OneDrive - Insper - Institudo de Ensino e Pesquisa\Insper\3 B\DP Ciência dos Dados\Untitled Folder\Ci-ncia-dos-Dados-DP

# %% [markdown]
# ### BASE DE DADOS

# %%
dados = pd.read_excel('cars.xlsx')
dados.dtypes
# Out:
# mpg            float64
# cylinders        int64
# cubicinches      int64
# hp               int64
# weightlbs        int64
# time-to-60       int64
# year             int64
# brand           object
# dtype: object

# %%
df = dados[['cylinders','hp','time-to-60']].copy()

# %%
df.loc[(dados.mpg>0)|(dados.mpg<1000), 'Consumo(Km/L)']=dados.mpg*0.425
df.loc[(dados.weightlbs>0)|(dados.weightlbs<100000), 'Peso(Kg)']=dados.weightlbs*0.453592
df.loc[(dados.cubicinches>0)|(dados.cubicinches<1000), 'Cilindradas(L)']=dados.cubicinches/0.061024/1000

# %%
df.rename(index=str, columns={"cylinders": "Cilindros", "hp": "Potência(hp)", "time-to-60":"0-100(s)" })
# Out:
#      Cilindros  Potência(hp)  0-100(s)  Consumo(Km/L)     Peso(Kg)  \
# 0            8           165        12         5.9500  1909.168728
# 1            4            71        14        13.5575   873.164600
# 2            8           140        11         7.2250  1564.438808
# 3            8           150        10         6.3750  1705.959512
# 4            4            63        17        12.9625   930.317192
# 5            8           125        17         9.7750  1769.008800
# 6            8           158        13         5.5250  1979.021896
# 7            8           215         9         5.9500  1955.888704
# 8            5            77        20        10.7950  1601.179760
# 9            4            62        17        16.0225   929.863600
# 10           4            70        17        14.4500  1018.314040
# 11           4            78        16        14.5775   992.459296
# 12           8           140        14         6.8000  1878.324472
# ...

# %% [markdown]
# ### ANÁLISE DESCRITIVA

# %% [markdown]
# ___
# ## MODELOS DE PREDIÇÃO

# %% [markdown]
# [O tópico C.PROCESSO E ESTATÍSTICAS DE VALIDAÇÃO estará dentro deste tópico. Organize-o aqui de forma clara!]
#
# [ORGANIZE AQUI TODOS OS MODELOS DE PREDIÇÃO NECESSÁRIOS NESTE PROJETO!]

# %% [markdown]
# o MODELO DE PREDIÇÃO PELA MÉDIA
#
# o MODELO DOS K VIZINHOS MAIS PRÓXIMOS (K-Nearest Neighbors Regression)
#
# o MODELO DE REGRESSÃO LINEAR (Multiple Linear Regression)
#
# o MODELO DE ÁRVORES DE REGRESSÃO (Decision Tree Regression)

# %% [markdown]
# ___
# ## CONCLUSÃO

# %% [markdown]
# ___
# ## REFERÊNCIAS BIBLIOGRÁFICAS
